# %%
import tensorflow as tf
from keras.layers import (
    Dense,
    Input,
    GlobalAveragePooling2D,
    Dropout,
    BatchNormalization,
    UpSampling2D,
    Conv2D,
    MaxPooling2D,
    AveragePooling2D,
    Flatten,
    Concatenate,
)
from tensorflow.keras.optimizers import Adam
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import CSVLogger
from keras.models import Model
from tensorflow.keras.applications import MobileNet, MobileNetV2
from tensorflow import keras

# import tensorflow_model_optimization as tfmot
from keras import backend as K
from tqdm import tqdm
import os
import sys
import numpy as np
import h5py
import matplotlib.pyplot as plt
import cv2
from module.const import *
from module import func, loss
import random

# %% [markdown]
# # データセット作成

# %%
# データセット
x_train = []
y_train = []
x_test = []
y_test = []
x_valid = []
y_valid = []
semantic_label_size = INPUT_SIZE
trans_lst = []
center = (INPUT_SIZE[0] / 2, INPUT_SIZE[1] / 2)
scale = 1.0
for i in [theta for theta in range(0, 180, 10)]:
    trans_lst.append(cv2.getRotationMatrix2D(center, i, scale))

    # for dir in ["train", "valid"]:
dataset = []
for path in os.listdir(DATA_DIR):
    path = os.path.join(DATA_DIR, path)
    with h5py.File(path, "r") as f:
        img = f["img"][:]
        label = f["label"][:]
    dataset.append((img, label))
random_idx = list(range(0, len(dataset)))

# データをランダムに取得するためのインデックス
random.shuffle(random_idx)
# データ取得。データ数が少ないため、auguentationを行う。回転、反転、明るさ調整を行い、学習データに追加。
positive_count = 0
for i, idx in enumerate(tqdm(random_idx)):
    img, label = dataset[idx]
    if i < len(random_idx) * 0.9:
        if np.any(label == 1):
            positive_count += 1
        # else:
        #     continue
        for trans in trans_lst:
            img_trans = cv2.warpAffine(img, trans, semantic_label_size)
            label_trans = cv2.warpAffine(label, trans, semantic_label_size)
            img_trans = func.augment_brightness(img_trans)
            x_train.append(img_trans)
            y_train.append(cv2.resize(label_trans, semantic_label_size))
            img_trans = np.fliplr(img_trans)
            img_trans = func.augment_brightness(img_trans)
            x_train.append(img_trans)
            y_train.append(cv2.resize(np.fliplr(label_trans), semantic_label_size))
        # img_trans = img
        # img_trans = func.augment_brightness(img_trans)
        # x_train.append(img_trans)
        # y_train.append(cv2.resize(label, semantic_label_size))
        # img_trans = np.fliplr(img_trans)
        # img_trans = func.augment_brightness(img_trans)
        # x_train.append(img_trans)
        # y_train.append(cv2.resize(np.fliplr(label), semantic_label_size))
    else:
        x_valid.append(img)
        y_valid.append(cv2.resize(label, semantic_label_size))
# Out:
# 100%|██████████| 133/133 [00:00<00:00, 181.61it/s]

# %%
print(len(x_train), len(x_valid))
plt.subplot(1, 2, 1)
plt.imshow(x_train[0])
plt.subplot(1, 2, 2)
plt.imshow(y_train[0])
plt.show()
# Out:
# 4320 13

# %%
x_train = np.array(x_train) / 255
y_train = np.array(y_train)
x_test = np.array(x_test) / 255
y_test = np.array(y_test)
x_valid = np.array(x_valid) / 255
y_valid = np.array(y_valid)

# %% [markdown]
# # モデルの定義

# %%
mobilenet = MobileNetV2(
    input_shape=(INPUT_SIZE[0], INPUT_SIZE[1], INPUT_CHANNEL),
    include_top=False,
    alpha=ALPHA,
    weights="imagenet",
)
mobilenet.summary()
complessed_mobilenet = Model(
    inputs=mobilenet.input, outputs=mobilenet.get_layer("block_6_expand_relu").output
)
for layer in complessed_mobilenet.layers:
    layer.trainable = False


semantic_model= tf.keras.models.Sequential(
    [
        complessed_mobilenet,
        Conv2D(
            filters=32,
            kernel_size=1,
            strides=1,
            padding="same",
            activation="relu",
        ),
        tf.keras.layers.BatchNormalization(),
        Conv2D(
            filters=32,
            kernel_size=1,
            strides=1,
            padding="same",
            activation="relu",
        ),
        tf.keras.layers.BatchNormalization(),
        Conv2D(
            filters=1,
            kernel_size=1,
            strides=1,
            padding="same",
            activation="sigmoid",
        ),
        tf.keras.layers.UpSampling2D(size=(2,2), interpolation="bilinear"), # 24
        Conv2D(
            filters=64,
            kernel_size=1,
            strides=1,
            padding="same",
            activation="relu",
        ),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.UpSampling2D(size=(2,2), interpolation="bilinear"),# 48
        Conv2D(
            filters=32,
            kernel_size=1,
            strides=1,
            padding="same",
            activation="relu",
        ),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.UpSampling2D(size=(2,2), interpolation="bilinear"),# 96
        Conv2D(
            filters=1,
            kernel_size=1,
            strides=1,
            padding="same",
            activation="sigmoid",
        ),]

)

semantic_model.summary()
# Out:
# Model: "mobilenetv2_0.75_96"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  Conv1 (Conv2D)                 (None, 48, 48, 24)   648         ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 48, 48, 24)   96          ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 48, 48, 24)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 48, 48, 24)  216         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 48, 48, 24)  96          ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 48, 48, 24)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 48, 48, 16)  384         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 48, 48, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 48, 48, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 48, 48, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 48, 48, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 49, 49, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 24, 24, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 24, 24, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 24, 24, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 24, 24, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 24, 24, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 24, 24, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 24, 24, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 24, 24, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 24, 24, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 24, 24, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 24, 24, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 24, 24, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 24, 24, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 24, 24, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 24, 24, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 24, 24, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 24, 24, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 25, 25, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 12, 12, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 12, 12, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 12, 12, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 12, 12, 24)   3456        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 12, 12, 24)  96          ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 12, 12, 144)  3456        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 12, 12, 144)  576        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 12, 12, 144)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 12, 12, 144)  1296       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 12, 12, 144)  576        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 12, 12, 144)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 12, 12, 24)   3456        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 12, 12, 24)  96          ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 12, 12, 24)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 12, 12, 144)  3456        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 12, 12, 144)  576        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 12, 12, 144)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 12, 12, 144)  1296       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 12, 12, 144)  576        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 12, 12, 144)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 12, 12, 24)   3456        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 12, 12, 24)  96          ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 12, 12, 24)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 12, 12, 144)  3456        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 12, 12, 144)  576        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 12, 12, 144)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 13, 13, 144)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 6, 6, 144)   1296        ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 6, 6, 144)   576         ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 6, 6, 144)    0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 6, 6, 48)     6912        ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 6, 6, 48)    192         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 6, 6, 288)    13824       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 6, 6, 288)   1152        ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 6, 6, 288)    0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 6, 6, 288)   2592        ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 6, 6, 288)   1152        ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 6, 6, 288)    0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 6, 6, 48)     13824       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 6, 6, 48)    192         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 6, 6, 48)     0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 6, 6, 288)    13824       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 6, 6, 288)   1152        ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 6, 6, 288)    0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 6, 6, 288)   2592        ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 6, 6, 288)   1152        ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 6, 6, 288)    0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 6, 6, 48)     13824       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 6, 6, 48)    192         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 6, 6, 48)     0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 6, 6, 288)    13824       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 6, 6, 288)   1152        ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 6, 6, 288)    0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 6, 6, 288)   2592        ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 6, 6, 288)   1152        ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 6, 6, 288)    0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 6, 6, 48)     13824       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 6, 6, 48)    192         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 6, 6, 48)     0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 6, 6, 288)    13824       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 6, 6, 288)   1152        ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 6, 6, 288)    0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 6, 6, 288)   2592        ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 6, 6, 288)   1152        ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 6, 6, 288)   0           ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 6, 6, 72)     20736       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 6, 6, 72)    288         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 6, 6, 432)    31104       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 6, 6, 432)   1728        ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 6, 6, 432)    0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 6, 6, 432)   3888        ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 6, 6, 432)   1728        ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 6, 6, 432)   0           ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 6, 6, 72)     31104       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 6, 6, 72)    288         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 6, 6, 72)     0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 6, 6, 432)    31104       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 6, 6, 432)   1728        ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 6, 6, 432)    0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 6, 6, 432)   3888        ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 6, 6, 432)   1728        ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 6, 6, 432)   0           ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 6, 6, 72)     31104       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 6, 6, 72)    288         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 6, 6, 72)     0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 6, 6, 432)    31104       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 6, 6, 432)   1728        ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 6, 6, 432)    0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 7, 7, 432)    0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 3, 3, 432)   3888        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 3, 3, 432)   1728        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 3, 3, 432)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 3, 3, 120)    51840       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 3, 3, 120)   480         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 3, 3, 720)    86400       ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 3, 3, 720)   2880        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 3, 3, 720)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 3, 3, 720)   6480        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 3, 3, 720)   2880        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 3, 3, 720)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 3, 3, 120)    86400       ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 3, 3, 120)   480         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 3, 3, 120)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 3, 3, 720)    86400       ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 3, 3, 720)   2880        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 3, 3, 720)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 3, 3, 720)   6480        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 3, 3, 720)   2880        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 3, 3, 720)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 3, 3, 120)    86400       ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 3, 3, 120)   480         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 3, 3, 120)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 3, 3, 720)    86400       ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 3, 3, 720)   2880        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 3, 3, 720)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 3, 3, 720)   6480        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 3, 3, 720)   2880        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 3, 3, 720)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 3, 3, 240)    172800      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 3, 3, 240)   960         ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 3, 3, 1280)   307200      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 3, 3, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 3, 3, 1280)   0           ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 1,382,064
# Trainable params: 1,355,424
# Non-trainable params: 26,640
# __________________________________________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model (Functional)          (None, 12, 12, 144)       48928
#
#  conv2d (Conv2D)             (None, 12, 12, 32)        4640
#
#  batch_normalization (BatchN  (None, 12, 12, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 32)        1056
#
#  batch_normalization_1 (Batc  (None, 12, 12, 32)       128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 1)         33
#
#  up_sampling2d (UpSampling2D  (None, 24, 24, 1)        0
#  )
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        128
#
#  batch_normalization_2 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  up_sampling2d_1 (UpSampling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 48, 48, 32)        2080
#
#  batch_normalization_3 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  up_sampling2d_2 (UpSampling  (None, 96, 96, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 96, 96, 1)         33
#
# =================================================================
# Total params: 57,538
# Trainable params: 8,290
# Non-trainable params: 49,248
# _________________________________________________________________

# %% [markdown]
# # 学習

# %%
semantic_model.compile(
    loss=loss.DiceLoss,
    optimizer=Adam(learning_rate=0.001),
    metrics=[loss.IoU],
)

semantic_model.fit(
    x_train,
    y_train,
    batch_size=32,
    epochs=50,
    validation_data=(x_valid, y_valid),
)
# Out:
# Epoch 1/50
# 135/135 [==============================] - 5s 12ms/step - loss: 0.7559 - IoU: 0.1427 - val_loss: 0.9899 - val_IoU: 0.0051
# Epoch 2/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.3674 - IoU: 0.4681 - val_loss: 1.0000 - val_IoU: 5.7714e-06
# Epoch 3/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.2490 - IoU: 0.6019 - val_loss: 1.0000 - val_IoU: 6.6521e-06
# Epoch 4/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.2283 - IoU: 0.6289 - val_loss: 0.7093 - val_IoU: 0.1701
# Epoch 5/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.2177 - IoU: 0.6430 - val_loss: 0.3121 - val_IoU: 0.5243
# Epoch 6/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.2120 - IoU: 0.6506 - val_loss: 0.1992 - val_IoU: 0.6678
# Epoch 7/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.2068 - IoU: 0.6576 - val_loss: 0.2384 - val_IoU: 0.6149
# Epoch 8/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.2049 - IoU: 0.6604 - val_loss: 0.1917 - val_IoU: 0.6782
# Epoch 9/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.2013 - IoU: 0.6652 - val_loss: 0.1702 - val_IoU: 0.7091
# Epoch 10/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1988 - IoU: 0.6688 - val_loss: 0.1731 - val_IoU: 0.7049
# Epoch 11/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1983 - IoU: 0.6695 - val_loss: 0.2730 - val_IoU: 0.5710
# Epoch 12/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1985 - IoU: 0.6692 - val_loss: 0.1974 - val_IoU: 0.6703
# Epoch 13/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1951 - IoU: 0.6740 - val_loss: 0.1992 - val_IoU: 0.6678
# Epoch 14/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1940 - IoU: 0.6756 - val_loss: 0.1704 - val_IoU: 0.7089
# Epoch 15/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1915 - IoU: 0.6790 - val_loss: 0.1875 - val_IoU: 0.6842
# Epoch 16/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1913 - IoU: 0.6793 - val_loss: 0.2778 - val_IoU: 0.5651
# Epoch 17/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1907 - IoU: 0.6802 - val_loss: 0.1998 - val_IoU: 0.6669
# Epoch 18/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1880 - IoU: 0.6840 - val_loss: 0.1586 - val_IoU: 0.7262
# Epoch 19/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1905 - IoU: 0.6805 - val_loss: 0.1807 - val_IoU: 0.6939
# Epoch 20/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1873 - IoU: 0.6850 - val_loss: 0.1805 - val_IoU: 0.6942
# Epoch 21/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1869 - IoU: 0.6856 - val_loss: 0.1628 - val_IoU: 0.7200
# Epoch 22/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1870 - IoU: 0.6854 - val_loss: 0.1759 - val_IoU: 0.7009
# Epoch 23/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1854 - IoU: 0.6876 - val_loss: 0.1558 - val_IoU: 0.7303
# Epoch 24/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1846 - IoU: 0.6888 - val_loss: 0.1578 - val_IoU: 0.7274
# Epoch 25/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1838 - IoU: 0.6900 - val_loss: 0.1732 - val_IoU: 0.7048
# Epoch 26/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1839 - IoU: 0.6897 - val_loss: 0.1909 - val_IoU: 0.6794
# Epoch 27/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1832 - IoU: 0.6908 - val_loss: 0.1694 - val_IoU: 0.7103
# Epoch 28/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1818 - IoU: 0.6928 - val_loss: 0.1932 - val_IoU: 0.6762
# Epoch 29/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1808 - IoU: 0.6941 - val_loss: 0.1868 - val_IoU: 0.6851
# Epoch 30/50
# 135/135 [==============================] - 1s 10ms/step - loss: 0.1819 - IoU: 0.6925 - val_loss: 0.1744 - val_IoU: 0.7030
# Epoch 31/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1805 - IoU: 0.6947 - val_loss: 0.1648 - val_IoU: 0.7170
# Epoch 32/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1815 - IoU: 0.6931 - val_loss: 0.1798 - val_IoU: 0.6952
# Epoch 33/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1797 - IoU: 0.6957 - val_loss: 0.1901 - val_IoU: 0.6805
# Epoch 34/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1795 - IoU: 0.6961 - val_loss: 0.1704 - val_IoU: 0.7088
# Epoch 35/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1793 - IoU: 0.6963 - val_loss: 0.1667 - val_IoU: 0.7142
# Epoch 36/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1799 - IoU: 0.6955 - val_loss: 0.1684 - val_IoU: 0.7118
# Epoch 37/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1805 - IoU: 0.6948 - val_loss: 0.1594 - val_IoU: 0.7251
# Epoch 38/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1784 - IoU: 0.6976 - val_loss: 0.1693 - val_IoU: 0.7105
# Epoch 39/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1773 - IoU: 0.6993 - val_loss: 0.1772 - val_IoU: 0.6989
# Epoch 40/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1788 - IoU: 0.6972 - val_loss: 0.1764 - val_IoU: 0.7001
# Epoch 41/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1770 - IoU: 0.6996 - val_loss: 0.1653 - val_IoU: 0.7163
# Epoch 42/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1773 - IoU: 0.6992 - val_loss: 0.1797 - val_IoU: 0.6953
# Epoch 43/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1774 - IoU: 0.6991 - val_loss: 0.1886 - val_IoU: 0.6826
# Epoch 44/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1784 - IoU: 0.6976 - val_loss: 0.1600 - val_IoU: 0.7241
# Epoch 45/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1780 - IoU: 0.6981 - val_loss: 0.1603 - val_IoU: 0.7236
# Epoch 46/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1767 - IoU: 0.7000 - val_loss: 0.2087 - val_IoU: 0.6546
# Epoch 47/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1742 - IoU: 0.7036 - val_loss: 0.1827 - val_IoU: 0.6910
# Epoch 48/50
# 135/135 [==============================] - 1s 9ms/step - loss: 0.1746 - IoU: 0.7031 - val_loss: 0.1588 - val_IoU: 0.7260
# Epoch 49/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1746 - IoU: 0.7031 - val_loss: 0.1889 - val_IoU: 0.6823
# Epoch 50/50
# 135/135 [==============================] - 1s 8ms/step - loss: 0.1755 - IoU: 0.7019 - val_loss: 0.1804 - val_IoU: 0.6944

# %% [markdown]
# # テスト

# %%
import shutil
test_img_lst = os.listdir("test")
test_result_dir = "test_result"
if os.path.exists(test_result_dir):
    shutil.rmtree(test_result_dir)
os.mkdir(test_result_dir)

# %%
for i, img_name in enumerate(test_img_lst):
    img_path = os.path.join("test", img_name)
    img = cv2.imread(img_path)
    img = cv2.resize(img, INPUT_SIZE)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = np.expand_dims(img, axis=0)
    img = img / 255
    pred = semantic_model.predict(img)
    pred = np.squeeze(pred)
    pred = np.where(pred > 0.5, 1, 0)
    plt.subplot(1, 2, 1)
    plt.imshow(img[0])
    plt.subplot(1, 2, 2)
    plt.imshow(pred)
    plt.savefig(os.path.join(test_result_dir, img_name))
    plt.close()

# %% [markdown]
# # モデルの変換
# ### 粗いセグメンテーションを実装するために、モデルを途中でちょん切る

# %%
def get_name_spresense_output_layer(model, idx_ketu):
    layer_name = model.layers[idx_ketu].name
    return layer_name

spresense_output_layer_name = get_name_spresense_output_layer(semantic_model, 5)
spresense_output_layer_name
# Out:
# 'conv2d_2'

# %%
semantic_model.summary()
spresense_model = Model(
    inputs=semantic_model.input, outputs=semantic_model.get_layer(spresense_output_layer_name).output
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model (Functional)          (None, 12, 12, 144)       48928
#
#  conv2d (Conv2D)             (None, 12, 12, 32)        4640
#
#  batch_normalization (BatchN  (None, 12, 12, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 32)        1056
#
#  batch_normalization_1 (Batc  (None, 12, 12, 32)       128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 1)         33
#
#  up_sampling2d (UpSampling2D  (None, 24, 24, 1)        0
#  )
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        128
#
#  batch_normalization_2 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  up_sampling2d_1 (UpSampling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 48, 48, 32)        2080
#
#  batch_normalization_3 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  up_sampling2d_2 (UpSampling  (None, 96, 96, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 96, 96, 1)         33
#
# =================================================================
# Total params: 57,538
# Trainable params: 8,290
# Non-trainable params: 49,248
# _________________________________________________________________

# %%
test_sprit_result_dir = "test_sprit_result" 
if os.path.exists(test_sprit_result_dir):
    shutil.rmtree(test_sprit_result_dir)
os.mkdir(test_sprit_result_dir)
for img_name in test_img_lst[::-1 ]:
    img_path = os.path.join("test", img_name)
    img = cv2.imread(img_path)
    img = cv2.resize(img, INPUT_SIZE)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = np.expand_dims(img, axis=0)
    img = img / 255
    pred = spresense_model.predict(img)
    pred = np.squeeze(pred)
    # pred_stats = scipy.stats.describe(pred, axis=None)
    mask_pred = np.where(pred >0.5, 1, 0)
    plt.subplot(1, 3, 1)
    plt.imshow(img[0])
    plt.subplot(1, 3, 2)
    plt.imshow(mask_pred)
    plt.subplot(1, 3, 3)
    plt.imshow(pred, vmin=0, vmax=1)
    # cbar = plt.colorbar(pred, ax=plt.gca())
    # cbar.set_label('Colorbar Label')  # カラーバーのラベルを設定
    # plt.show()
    plt.savefig(os.path.join(test_sprit_result_dir, img_name))
    plt.close()

# %% [markdown]
# # spresense用にモデル変換

# %%
if os.path.exists(MODEL_DIR) == False:
    os.mkdir(MODEL_DIR)
spresense_model.save(FULL_MODEL_PATH)
conveter = tf.lite.TFLiteConverter.from_keras_model(spresense_model)
tflite_model = conveter.convert()
float_model_size = len(tflite_model) / 1024 / 1024
print(f"float model size: {float_model_size} MB")
open(TFLITE_MODEL_PATH, "wb").write(tflite_model)


import binascii


def convert_to_c_array(bytes) -> str:
    hexstr = binascii.hexlify(bytes).decode("UTF-8")
    hexstr = hexstr.upper()
    array = ["0x" + hexstr[i : i + 2] for i in range(0, len(hexstr), 2)]
    array = [array[i : i + 10] for i in range(0, len(array), 10)]
    return ",\n  ".join([", ".join(e) for e in array])


tflite_binary = open(TFLITE_MODEL_PATH, "rb").read()
ascii_bytes = convert_to_c_array(tflite_binary)
header_file = (
    "const unsigned char model_tflite[] = {\n  "
    + ascii_bytes
    + "\n};\nunsigned int model_tflite_len = "
    + str(len(tflite_binary))
    + ";"
)
# print(c_file)
open(HEADER_MODEL_PATH, "w").write(header_file)
open(SPRESENSE_HEADER_MODEL_PATH, "w").write(header_file)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\oosim\AppData\Local\Temp\tmphr9_l2yo\assets
# INFO:tensorflow:Assets written to: C:\Users\oosim\AppData\Local\Temp\tmphr9_l2yo\assets
# float model size: 0.20481491088867188 MB
# 1331618

# %%
print("--------start quantization--------")


def representative_dataset_gen():
    for i in range(len(x_valid)):
        input_image = tf.cast(x_valid[i], tf.float32)
        input_image = tf.reshape(
            input_image, [1, INPUT_SIZE[0], INPUT_SIZE[1], INPUT_CHANNEL]
        )
        yield ([input_image])


converter = tf.lite.TFLiteConverter.from_keras_model(spresense_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
# converter.inference_input_type = tf.int8
# converter.inference_output_type = tf.int8
tflite_quant_model = converter.convert()

tflite_quant_model_path = os.path.join(MODEL_DIR, "model_quant.tflite")
with open(tflite_quant_model_path, "wb") as f:
    f.write(tflite_quant_model)
spresense_quant_model_path = os.path.join(MODEL_DIR, "spresense_model_quant.h")
tflite_binary = open(tflite_quant_model_path, "rb").read()
ascii_bytes = convert_to_c_array(tflite_binary)
header_file = (
    "const unsigned char model_tflite[] = {\n  "
    + ascii_bytes
    + "\n};\nunsigned int model_tflite_len = "
    + str(len(tflite_binary))
    + ";"
)

open(HEADER_QUANT_MODEL_PATH, "w").write(header_file)
open(SPRESENSE_HEADER_QUANT_MODEL_PATH, "w").write(header_file)
# Out:
# --------start quantization--------
# INFO:tensorflow:Assets written to: C:\Users\oosim\AppData\Local\Temp\tmp7bydpvr5\assets
# INFO:tensorflow:Assets written to: C:\Users\oosim\AppData\Local\Temp\tmp7bydpvr5\assets
# c:\Users\oosim\Anaconda3\envs\fuc\lib\site-packages\tensorflow\lite\python\convert.py:746: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# 713378
